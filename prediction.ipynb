# %%
import pandas as pd

stock = input("Please enter the name of the stock:  ")

stock_csv = stock + '.csv'

df = pd.read_csv(stock_csv)

df
# Out:
# Please enter the name of the stock:   Apple
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086999
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091737
# ...           ...         ...         ...         ...         ...         ...
# 10983  2024-07-10  229.300003  233.080002  229.250000  232.979996  232.979996
# 10984  2024-07-11  231.389999  232.389999  225.770004  227.570007  227.570007
# 10985  2024-07-12  228.919998  232.639999  228.679993  230.539993  230.539993
# 10986  2024-07-15  236.479996  237.229996  233.089996  234.399994  234.399994
# 10987  2024-07-16  235.205002  236.270004  233.009995  234.010101  234.010101
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 10983   62627700
# 10984   64710600
# 10985   53008200
# 10986   62549700
# 10987   20356284
#
# [10988 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#              Date       Close
# 0      1980-12-12    0.128348
# 1      1980-12-15    0.121652
# 2      1980-12-16    0.112723
# 3      1980-12-17    0.115513
# 4      1980-12-18    0.118862
# ...           ...         ...
# 10983  2024-07-10  232.979996
# 10984  2024-07-11  227.570007
# 10985  2024-07-12  230.539993
# 10986  2024-07-15  234.399994
# 10987  2024-07-16  234.010101
#
# [10988 rows x 2 columns]

# %%
df['Date']
# Out:
# 0        1980-12-12
# 1        1980-12-15
# 2        1980-12-16
# 3        1980-12-17
# 4        1980-12-18
#             ...
# 10983    2024-07-10
# 10984    2024-07-11
# 10985    2024-07-12
# 10986    2024-07-15
# 10987    2024-07-16
# Name: Date, Length: 10988, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split=s.split('-')
    year,month, day=int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object =str_to_datetime('1986-03-13')
datetime_object
# Out:
# datetime.datetime(1986, 3, 13, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Tonmoy\AppData\Local\Temp\ipykernel_29344\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0       1980-12-12
# 1       1980-12-15
# 2       1980-12-16
# 3       1980-12-17
# 4       1980-12-18
#            ...
# 10983   2024-07-10
# 10984   2024-07-11
# 10985   2024-07-12
# 10986   2024-07-15
# 10987   2024-07-16
# Name: Date, Length: 10988, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-07-10  232.979996
# 2024-07-11  227.570007
# 2024-07-12  230.539993
# 2024-07-15  234.399994
# 2024-07-16  234.010101
#
# [10988 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np
import pandas as pd
import datetime

def str_to_datetime(date_str):
    return datetime.datetime.strptime(date_str, '%Y-%m-%d')

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    first_date = str_to_datetime(first_date_str)
    last_date = str_to_datetime(last_date_str)

    target_date = first_date

    dates = []
    X, Y = [], []

    last_time = False
    while True:
        df_subset = dataframe.loc[:target_date].tail(n + 1)

        if len(df_subset) != n + 1:
            print(f'Error: Window of size {n} is too large for date {target_date}')
            return

        values = df_subset['Close'].to_numpy()
        x, y = values[:-1], values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)

        next_week = dataframe.loc[target_date:target_date + datetime.timedelta(days=7)]
        next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
        next_date_str = next_datetime_str.split('T')[0]
        year_month_day = next_date_str.split('-')
        year, month, day = year_month_day
        next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

        if last_time:
            break

        target_date = next_date

        if target_date == last_date:
            last_time = True

    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates

    X = np.array(X)
    for i in range(0, n):
        ret_df[f'Target-{n - i}'] = X[:, i]

    ret_df['Target'] = Y

    return ret_df

# Prompt the user to enter the start date and end date
start_date = input("Please enter the start date (YYYY-MM-DD): ")
end_date = input("Please enter the end date (YYYY-MM-DD): ")

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, start_date, end_date, n=3)
windowed_df
# Out:
# Please enter the start date (YYYY-MM-DD):  2023-07-17
# Please enter the end date (YYYY-MM-DD):  2024-07-10
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2023-07-17  189.770004  190.539993  190.690002  193.990005
# 1    2023-07-18  190.539993  190.690002  193.990005  193.729996
# 2    2023-07-19  190.690002  193.990005  193.729996  195.100006
# 3    2023-07-20  193.990005  193.729996  195.100006  193.130005
# 4    2023-07-21  193.729996  195.100006  193.130005  191.940002
# ..          ...         ...         ...         ...         ...
# 243  2024-07-03  210.619995  216.750000  220.270004  221.550003
# 244  2024-07-05  216.750000  220.270004  221.550003  226.339996
# 245  2024-07-08  220.270004  221.550003  226.339996  227.820007
# 246  2024-07-09  221.550003  226.339996  227.820007  228.679993
# 247  2024-07-10  226.339996  227.820007  228.679993  232.979996
#
# [248 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((248,), (248, 3, 1), (248,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 33025.3633 - mean_absolute_error: 181.5145 - val_loss: 34218.5000 - val_mean_absolute_error: 184.8504
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32680.2344 - mean_absolute_error: 180.5724 - val_loss: 33955.5703 - val_mean_absolute_error: 184.1379
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32631.3633 - mean_absolute_error: 180.4316 - val_loss: 33708.0039 - val_mean_absolute_error: 183.4643
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32358.0352 - mean_absolute_error: 179.6571 - val_loss: 33379.2031 - val_mean_absolute_error: 182.5661
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31907.6719 - mean_absolute_error: 178.4117 - val_loss: 32994.6641 - val_mean_absolute_error: 181.5100
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31514.9648 - mean_absolute_error: 177.3080 - val_loss: 32559.7168 - val_mean_absolute_error: 180.3077
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31141.6582 - mean_absolute_error: 176.2423 - val_loss: 31928.5879 - val_mean_absolute_error: 178.5483
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30568.6445 - mean_absolute_error: 174.6088 - val_loss: 30878.8320 - val_mean_absolute_error: 175.5834
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29164.2988 - mean_absolute_error: 170.5390 - val_loss: 29468.9570 - val_mean_absolute_error: 171.5221
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28055.5039 - mean_absolute_error: 167.2622 - val_loss: 27882.9805 - val_mean_absolute_error: 166.8344
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26153.5703 - mean_absolute_error: 161.4663 - val_loss: 25790.3867 - val_mean_absolute_error: 160.4375
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24160.4707 - mean_absolute_error: 155.1750 - val_loss: 22865.9941 - val_mean_absolute_error: 151.0500
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21095.9961 - mean_absolute_error: 144.9458 - val_loss: 19807.8301 - val_mean_absolute_error: 140.5638
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18006.4238 - mean_absolute_error: 133.8643 - val_loss: 16621.2285 - val_mean_absolute_error: 128.7320
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15018.6738 - mean_absolute_error: 122.1853 - val_loss: 13406.1055 - val_mean_absolute_error: 115.5696
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11713.1387 - mean_absolute_error: 107.8099 - val_loss: 10033.3291 - val_mean_absolute_error: 99.9212
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8715.4922 - mean_absolute_error: 92.8089 - val_loss: 7161.3638 - val_mean_absolute_error: 84.3353
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6025.2192 - mean_absolute_error: 76.9841 - val_loss: 4603.4648 - val_mean_absolute_error: 67.4813
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3537.6392 - mean_absolute_error: 58.7527 - val_loss: 2572.7471 - val_mean_absolute_error: 50.2343
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1917.1776 - mean_absolute_error: 42.6552 - val_loss: 1196.2047 - val_mean_absolute_error: 33.8615
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 789.6382 - mean_absolute_error: 26.4514 - val_loss: 387.8547 - val_mean_absolute_error: 18.3713
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 206.6859 - mean_absolute_error: 11.6467 - val_loss: 63.6702 - val_mean_absolute_error: 7.0439
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 83.8905 - mean_absolute_error: 7.9371 - val_loss: 53.6486 - val_mean_absolute_error: 5.3817
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 114.7259 - mean_absolute_error: 8.9661 - val_loss: 54.1387 - val_mean_absolute_error: 5.3850
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 123.2418 - mean_absolute_error: 9.5467 - val_loss: 48.6888 - val_mean_absolute_error: 5.6071
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 92.6442 - mean_absolute_error: 8.2946 - val_loss: 53.6147 - val_mean_absolute_error: 6.1967
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 88.9467 - mean_absolute_error: 8.3067 - val_loss: 63.9924 - val_mean_absolute_error: 7.1080
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80.9424 - mean_absolute_error: 7.8801 - val_loss: 70.6683 - val_mean_absolute_error: 7.6357
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.9311 - mean_absolute_error: 7.5208 - val_loss: 69.7380 - val_mean_absolute_error: 7.5676
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80.8521 - mean_absolute_error: 7.8759 - val_loss: 69.1115 - val_mean_absolute_error: 7.5208
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.5513 - mean_absolute_error: 7.6021 - val_loss: 66.1555 - val_mean_absolute_error: 7.2899
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 84.2867 - mean_absolute_error: 8.0857 - val_loss: 62.5494 - val_mean_absolute_error: 6.9802
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.6696 - mean_absolute_error: 7.5594 - val_loss: 62.7924 - val_mean_absolute_error: 7.0036
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 73.1153 - mean_absolute_error: 7.3298 - val_loss: 64.8680 - val_mean_absolute_error: 7.1868
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.1635 - mean_absolute_error: 7.5181 - val_loss: 65.4537 - val_mean_absolute_error: 7.2359
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 74.8491 - mean_absolute_error: 7.4438 - val_loss: 64.9127 - val_mean_absolute_error: 7.1910
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.4562 - mean_absolute_error: 7.5351 - val_loss: 64.7520 - val_mean_absolute_error: 7.1780
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 79.4717 - mean_absolute_error: 7.7717 - val_loss: 62.0761 - val_mean_absolute_error: 6.9451
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.4100 - mean_absolute_error: 7.6534 - val_loss: 61.8992 - val_mean_absolute_error: 6.9319
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 81.3116 - mean_absolute_error: 7.9953 - val_loss: 65.3986 - val_mean_absolute_error: 7.2314
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 78.1207 - mean_absolute_error: 7.6410 - val_loss: 66.0545 - val_mean_absolute_error: 7.2860
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.3039 - mean_absolute_error: 7.6231 - val_loss: 62.5673 - val_mean_absolute_error: 6.9880
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.8671 - mean_absolute_error: 7.6174 - val_loss: 62.2959 - val_mean_absolute_error: 6.9646
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 79.3643 - mean_absolute_error: 7.7686 - val_loss: 64.1351 - val_mean_absolute_error: 7.1277
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.1534 - mean_absolute_error: 7.4967 - val_loss: 64.8396 - val_mean_absolute_error: 7.1877
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.2167 - mean_absolute_error: 7.5819 - val_loss: 62.9093 - val_mean_absolute_error: 7.0206
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.9828 - mean_absolute_error: 7.7562 - val_loss: 62.8153 - val_mean_absolute_error: 7.0126
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 82.0252 - mean_absolute_error: 7.9496 - val_loss: 63.3545 - val_mean_absolute_error: 7.0637
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.8872 - mean_absolute_error: 7.6660 - val_loss: 65.8911 - val_mean_absolute_error: 7.3113
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 74.3211 - mean_absolute_error: 7.5196 - val_loss: 67.6395 - val_mean_absolute_error: 7.4749
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.8811 - mean_absolute_error: 7.2370 - val_loss: 66.7265 - val_mean_absolute_error: 7.4168
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80.1126 - mean_absolute_error: 7.8414 - val_loss: 58.0970 - val_mean_absolute_error: 6.6987
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 78.6269 - mean_absolute_error: 7.7789 - val_loss: 57.5321 - val_mean_absolute_error: 6.6981
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 73.1612 - mean_absolute_error: 7.4870 - val_loss: 66.2414 - val_mean_absolute_error: 7.4480
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 74.2023 - mean_absolute_error: 7.4621 - val_loss: 60.8746 - val_mean_absolute_error: 7.0849
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.1317 - mean_absolute_error: 7.1202 - val_loss: 62.6289 - val_mean_absolute_error: 7.2837
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 62.0556 - mean_absolute_error: 6.7572 - val_loss: 45.5275 - val_mean_absolute_error: 5.7917
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.7390 - mean_absolute_error: 6.9078 - val_loss: 56.7630 - val_mean_absolute_error: 6.8936
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.8451 - mean_absolute_error: 6.9104 - val_loss: 44.4162 - val_mean_absolute_error: 5.8198
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.5209 - mean_absolute_error: 6.4995 - val_loss: 48.0757 - val_mean_absolute_error: 6.2173
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.4334 - mean_absolute_error: 6.5582 - val_loss: 46.8741 - val_mean_absolute_error: 6.1644
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.4808 - mean_absolute_error: 5.8508 - val_loss: 38.7918 - val_mean_absolute_error: 5.3899
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.1272 - mean_absolute_error: 6.5083 - val_loss: 51.2583 - val_mean_absolute_error: 6.5708
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.5313 - mean_absolute_error: 6.2019 - val_loss: 36.6232 - val_mean_absolute_error: 5.2558
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.4658 - mean_absolute_error: 6.2319 - val_loss: 49.7759 - val_mean_absolute_error: 6.4836
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 49.8693 - mean_absolute_error: 5.9403 - val_loss: 31.7780 - val_mean_absolute_error: 4.8820
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.6328 - mean_absolute_error: 5.8344 - val_loss: 50.8071 - val_mean_absolute_error: 6.5425
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.8676 - mean_absolute_error: 5.7886 - val_loss: 41.2364 - val_mean_absolute_error: 5.8530
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.6404 - mean_absolute_error: 5.0816 - val_loss: 32.2363 - val_mean_absolute_error: 5.0787
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.9064 - mean_absolute_error: 5.2148 - val_loss: 41.0770 - val_mean_absolute_error: 5.8313
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.8266 - mean_absolute_error: 4.7111 - val_loss: 27.9833 - val_mean_absolute_error: 4.6881
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9431 - mean_absolute_error: 5.0180 - val_loss: 22.1848 - val_mean_absolute_error: 4.0690
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.7162 - mean_absolute_error: 5.4556 - val_loss: 52.1952 - val_mean_absolute_error: 6.5907
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.7656 - mean_absolute_error: 4.9974 - val_loss: 25.6388 - val_mean_absolute_error: 4.4798
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.0865 - mean_absolute_error: 4.7833 - val_loss: 19.9337 - val_mean_absolute_error: 3.8383
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.8369 - mean_absolute_error: 5.0476 - val_loss: 36.6509 - val_mean_absolute_error: 5.4440
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.9279 - mean_absolute_error: 4.4934 - val_loss: 21.3803 - val_mean_absolute_error: 4.0447
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.2765 - mean_absolute_error: 4.3742 - val_loss: 23.3026 - val_mean_absolute_error: 4.2569
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.8242 - mean_absolute_error: 4.6215 - val_loss: 28.2762 - val_mean_absolute_error: 4.7159
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.3264 - mean_absolute_error: 4.3599 - val_loss: 26.7187 - val_mean_absolute_error: 4.5627
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.6961 - mean_absolute_error: 3.9825 - val_loss: 19.3270 - val_mean_absolute_error: 3.8199
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.2354 - mean_absolute_error: 3.7769 - val_loss: 18.5636 - val_mean_absolute_error: 3.7293
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3824 - mean_absolute_error: 3.8678 - val_loss: 14.0599 - val_mean_absolute_error: 3.2528
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.2961 - mean_absolute_error: 3.7527 - val_loss: 18.9480 - val_mean_absolute_error: 3.7426
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.0299 - mean_absolute_error: 3.6280 - val_loss: 18.5591 - val_mean_absolute_error: 3.6840
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.1079 - mean_absolute_error: 3.4304 - val_loss: 15.8959 - val_mean_absolute_error: 3.3946
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1889 - mean_absolute_error: 3.6617 - val_loss: 28.4940 - val_mean_absolute_error: 4.8421
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.4705 - mean_absolute_error: 3.5807 - val_loss: 15.4552 - val_mean_absolute_error: 3.3239
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.0438 - mean_absolute_error: 3.3534 - val_loss: 13.5576 - val_mean_absolute_error: 3.1128
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.6202 - mean_absolute_error: 3.4579 - val_loss: 15.7599 - val_mean_absolute_error: 3.3707
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.9110 - mean_absolute_error: 3.2295 - val_loss: 12.3236 - val_mean_absolute_error: 2.9383
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.3815 - mean_absolute_error: 3.2187 - val_loss: 12.1251 - val_mean_absolute_error: 2.9129
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3926 - mean_absolute_error: 3.1052 - val_loss: 10.1423 - val_mean_absolute_error: 2.6761
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.7967 - mean_absolute_error: 3.1492 - val_loss: 11.2476 - val_mean_absolute_error: 2.7878
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5755 - mean_absolute_error: 3.0074 - val_loss: 9.7049 - val_mean_absolute_error: 2.5787
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.9485 - mean_absolute_error: 2.9293 - val_loss: 10.5995 - val_mean_absolute_error: 2.7044
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.7233 - mean_absolute_error: 2.8935 - val_loss: 11.4349 - val_mean_absolute_error: 2.8668
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.1865 - mean_absolute_error: 2.9051 - val_loss: 16.8861 - val_mean_absolute_error: 3.5859
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.5237 - mean_absolute_error: 2.8263 - val_loss: 32.7699 - val_mean_absolute_error: 5.1872
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.2409 - mean_absolute_error: 3.1775 - val_loss: 21.3802 - val_mean_absolute_error: 4.1108

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
