# %%
import pandas as pd

stock = input("Please enter the name of the stock:  ")

stock_csv = stock + '.csv'

df = pd.read_csv(stock_csv)

df
# Out:
# Please enter the name of the stock:   MSFT
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060055
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062199
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063272
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061663
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060591
# ...          ...         ...         ...         ...         ...         ...
# 9650  2024-06-28  453.070007  455.380005  446.410004  446.950012  446.950012
# 9651  2024-07-01  448.660004  457.369995  445.660004  456.730011  456.730011
# 9652  2024-07-02  453.200012  459.589996  453.109985  459.279999  459.279999
# 9653  2024-07-03  458.190002  461.019989  457.880005  460.769989  460.769989
# 9654  2024-07-05  459.609985  468.350006  458.970001  467.559998  467.559998
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9650    28362300
# 9651    17662800
# 9652    13979800
# 9653     9932800
# 9654    15980200
#
# [9655 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9650  2024-06-28  446.950012
# 9651  2024-07-01  456.730011
# 9652  2024-07-02  459.279999
# 9653  2024-07-03  460.769989
# 9654  2024-07-05  467.559998
#
# [9655 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9650    2024-06-28
# 9651    2024-07-01
# 9652    2024-07-02
# 9653    2024-07-03
# 9654    2024-07-05
# Name: Date, Length: 9655, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split=s.split('-')
    year,month, day=int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object =str_to_datetime('1986-03-13')
datetime_object
# Out:
# datetime.datetime(1986, 3, 13, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Tonmoy\AppData\Local\Temp\ipykernel_33700\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9650   2024-06-28
# 9651   2024-07-01
# 9652   2024-07-02
# 9653   2024-07-03
# 9654   2024-07-05
# Name: Date, Length: 9655, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-06-28  446.950012
# 2024-07-01  456.730011
# 2024-07-02  459.279999
# 2024-07-03  460.769989
# 2024-07-05  467.559998
#
# [9655 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np
import pandas as pd
import datetime

def str_to_datetime(date_str):
    return datetime.datetime.strptime(date_str, '%Y-%m-%d')

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    first_date = str_to_datetime(first_date_str)
    last_date = str_to_datetime(last_date_str)

    target_date = first_date

    dates = []
    X, Y = [], []

    last_time = False
    while True:
        df_subset = dataframe.loc[:target_date].tail(n + 1)

        if len(df_subset) != n + 1:
            print(f'Error: Window of size {n} is too large for date {target_date}')
            return

        values = df_subset['Close'].to_numpy()
        x, y = values[:-1], values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)

        next_week = dataframe.loc[target_date:target_date + datetime.timedelta(days=7)]
        next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
        next_date_str = next_datetime_str.split('T')[0]
        year_month_day = next_date_str.split('-')
        year, month, day = year_month_day
        next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

        if last_time:
            break

        target_date = next_date

        if target_date == last_date:
            last_time = True

    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates

    X = np.array(X)
    for i in range(0, n):
        ret_df[f'Target-{n - i}'] = X[:, i]

    ret_df['Target'] = Y

    return ret_df

# Prompt the user to enter the start date and end date
start_date = input("Please enter the start date (YYYY-MM-DD): ")
end_date = input("Please enter the end date (YYYY-MM-DD): ")

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, start_date, end_date, n=3)
windowed_df
# Out:
# Please enter the start date (YYYY-MM-DD):  2023-07-07
# Please enter the end date (YYYY-MM-DD):  2024-07-03
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1308.4476 - mean_absolute_error: 32.1665 - val_loss: 2239.0400 - val_mean_absolute_error: 45.8992
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1291.3821 - mean_absolute_error: 31.3981 - val_loss: 2246.5259 - val_mean_absolute_error: 45.9806
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1314.5028 - mean_absolute_error: 31.9610 - val_loss: 2276.8225 - val_mean_absolute_error: 46.3089
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1307.8534 - mean_absolute_error: 32.0864 - val_loss: 2327.2085 - val_mean_absolute_error: 46.8498
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1353.0966 - mean_absolute_error: 32.4141 - val_loss: 2353.4209 - val_mean_absolute_error: 47.1287
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1404.4036 - mean_absolute_error: 33.6880 - val_loss: 2345.9551 - val_mean_absolute_error: 47.0494
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1316.1675 - mean_absolute_error: 31.9630 - val_loss: 2317.0359 - val_mean_absolute_error: 46.7411
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1343.0311 - mean_absolute_error: 32.4721 - val_loss: 2307.0208 - val_mean_absolute_error: 46.6338
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1411.2629 - mean_absolute_error: 33.6242 - val_loss: 2253.5312 - val_mean_absolute_error: 46.0568
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1356.9669 - mean_absolute_error: 32.7232 - val_loss: 2224.0542 - val_mean_absolute_error: 45.7356
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1354.4440 - mean_absolute_error: 32.6428 - val_loss: 2205.2998 - val_mean_absolute_error: 45.5301
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1324.1646 - mean_absolute_error: 31.9262 - val_loss: 2209.6023 - val_mean_absolute_error: 45.5775
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1342.8176 - mean_absolute_error: 32.5633 - val_loss: 2265.0444 - val_mean_absolute_error: 46.1846
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1355.4695 - mean_absolute_error: 32.5902 - val_loss: 2429.1907 - val_mean_absolute_error: 47.9584
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1381.2556 - mean_absolute_error: 33.1781 - val_loss: 2150.6526 - val_mean_absolute_error: 44.9396
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1314.7849 - mean_absolute_error: 32.0095 - val_loss: 2217.0229 - val_mean_absolute_error: 45.6927
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1246.1858 - mean_absolute_error: 31.2663 - val_loss: 2297.1316 - val_mean_absolute_error: 46.5754
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1258.1240 - mean_absolute_error: 30.9509 - val_loss: 2265.7139 - val_mean_absolute_error: 46.2410
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1311.3174 - mean_absolute_error: 32.3454 - val_loss: 2219.6536 - val_mean_absolute_error: 45.7417
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1247.8101 - mean_absolute_error: 30.9098 - val_loss: 2276.0532 - val_mean_absolute_error: 46.3615
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1213.6150 - mean_absolute_error: 30.5495 - val_loss: 2342.7397 - val_mean_absolute_error: 47.0895
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1322.1096 - mean_absolute_error: 32.5463 - val_loss: 2573.5500 - val_mean_absolute_error: 49.4912
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1287.3558 - mean_absolute_error: 32.2370 - val_loss: 2105.1829 - val_mean_absolute_error: 44.4995
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1217.4028 - mean_absolute_error: 30.7877 - val_loss: 2625.4568 - val_mean_absolute_error: 50.0623
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1147.8485 - mean_absolute_error: 30.0969 - val_loss: 2165.5332 - val_mean_absolute_error: 45.2458
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1123.7762 - mean_absolute_error: 29.4917 - val_loss: 2057.7747 - val_mean_absolute_error: 44.0606
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1155.3457 - mean_absolute_error: 29.8453 - val_loss: 2078.2410 - val_mean_absolute_error: 44.2513
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1171.5677 - mean_absolute_error: 30.4610 - val_loss: 2048.9258 - val_mean_absolute_error: 44.0034
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1057.4095 - mean_absolute_error: 28.7464 - val_loss: 1684.1228 - val_mean_absolute_error: 39.6055
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1063.5509 - mean_absolute_error: 29.0130 - val_loss: 1854.4163 - val_mean_absolute_error: 41.7542
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 982.6743 - mean_absolute_error: 27.5618 - val_loss: 2067.6514 - val_mean_absolute_error: 44.3057
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 918.0126 - mean_absolute_error: 26.1184 - val_loss: 2144.0806 - val_mean_absolute_error: 45.2138
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 942.9580 - mean_absolute_error: 26.8550 - val_loss: 1248.4027 - val_mean_absolute_error: 33.7198
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 986.1265 - mean_absolute_error: 27.7629 - val_loss: 2528.8103 - val_mean_absolute_error: 49.3691
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 997.2792 - mean_absolute_error: 26.5572 - val_loss: 1195.4735 - val_mean_absolute_error: 33.0211
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 848.6616 - mean_absolute_error: 25.5185 - val_loss: 1495.0856 - val_mean_absolute_error: 37.4169
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 721.2748 - mean_absolute_error: 23.4283 - val_loss: 1056.7483 - val_mean_absolute_error: 30.9152
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 780.8690 - mean_absolute_error: 24.6808 - val_loss: 1798.5249 - val_mean_absolute_error: 41.3871
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 808.8614 - mean_absolute_error: 24.4642 - val_loss: 1722.7640 - val_mean_absolute_error: 40.4924
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 650.8252 - mean_absolute_error: 21.5591 - val_loss: 990.7160 - val_mean_absolute_error: 29.9952
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 608.6648 - mean_absolute_error: 21.2625 - val_loss: 1094.7046 - val_mean_absolute_error: 31.7772
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 567.8243 - mean_absolute_error: 20.9743 - val_loss: 1452.5099 - val_mean_absolute_error: 37.1209
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 500.7665 - mean_absolute_error: 19.0437 - val_loss: 1170.7430 - val_mean_absolute_error: 33.0868
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 507.3665 - mean_absolute_error: 19.1395 - val_loss: 910.3095 - val_mean_absolute_error: 28.8984
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 432.0935 - mean_absolute_error: 17.8599 - val_loss: 783.2440 - val_mean_absolute_error: 26.6272
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 402.0391 - mean_absolute_error: 17.3013 - val_loss: 592.5333 - val_mean_absolute_error: 22.7406
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 463.1698 - mean_absolute_error: 19.2397 - val_loss: 877.5740 - val_mean_absolute_error: 28.5190
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 334.4349 - mean_absolute_error: 15.7433 - val_loss: 1152.4999 - val_mean_absolute_error: 33.0901
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 330.6554 - mean_absolute_error: 15.1529 - val_loss: 614.5008 - val_mean_absolute_error: 23.4663
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 265.2840 - mean_absolute_error: 13.8083 - val_loss: 521.3718 - val_mean_absolute_error: 21.4119
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 243.2840 - mean_absolute_error: 13.2010 - val_loss: 450.4250 - val_mean_absolute_error: 19.8074
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 189.9913 - mean_absolute_error: 11.3768 - val_loss: 334.6626 - val_mean_absolute_error: 16.8569

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
