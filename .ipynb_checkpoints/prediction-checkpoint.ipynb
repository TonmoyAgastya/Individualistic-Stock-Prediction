# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from copy import deepcopy
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.optimizers import Adam


def str_to_datetime(date_str):
    return datetime.datetime.strptime(date_str, '%Y-%m-%d')


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    first_date = str_to_datetime(first_date_str)
    last_date = str_to_datetime(last_date_str)

    target_date = first_date
    dates = []
    X, Y = [], []

    last_time = False
    while True:
        df_subset = dataframe.loc[:target_date].tail(n + 1)

        if len(df_subset) != n + 1:
            print(f'Error: Window of size {n} is too large for date {target_date}')
            return

        values = df_subset['Close'].to_numpy()
        x, y = values[:-1], values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)

        next_week = dataframe.loc[target_date:target_date + datetime.timedelta(days=7)]
        next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
        next_date_str = next_datetime_str.split('T')[0]
        year_month_day = next_date_str.split('-')
        year, month, day = year_month_day
        next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

        if last_time:
            break

        target_date = next_date

        if target_date == last_date:
            last_time = True

    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates

    X = np.array(X)
    for i in range(0, n):
        ret_df[f'Target-{n - i}'] = X[:, i]

    ret_df['Target'] = Y

    return ret_df

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    dates = df_as_np[:, 0]

    middle_matrix = df_as_np[:, 1:-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    Y = df_as_np[:, -1]

    return dates, X.astype(np.float32), Y.astype(np.float32)


stock = input("Please enter the name of the stock: ")
stock_csv = stock + '.csv'
df = pd.read_csv(stock_csv)


df = df[['Date', 'Close']]
df['Date'] = df['Date'].apply(str_to_datetime)
df.index = df.pop('Date')


start_date = input("Please enter the start date (YYYY-MM-DD): ")
end_date = input("Please enter the end date (YYYY-MM-DD): ")


windowed_df = df_to_windowed_df(df, start_date, end_date, n=3)


dates, X, y = windowed_df_to_date_X_y(windowed_df)
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]


plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)
plt.legend(['Train', 'Validation', 'Test'])
plt.show()


model = Sequential([
    Input((3, 1)),
    LSTM(64),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)


train_predictions = model.predict(X_train).flatten()
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
plt.show()


val_predictions = model.predict(X_val).flatten()


plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
plt.show()


test_predictions = model.predict(X_test).flatten()
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
plt.show()


model.save('stock_prediction_model.keras')


loaded_model = load_model('stock_prediction_model.keras')

#
recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 'Training Observations',
            'Validation Predictions', 'Validation Observations',
            'Testing Predictions', 'Testing Observations',
            'Recursive Predictions'])
plt.show()
# Out:
# Please enter the name of the stock:  Amazon
# Please enter the start date (YYYY-MM-DD):  2023-07-17
# Please enter the end date (YYYY-MM-DD):  2024-07-10
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 23730.2949 - mean_absolute_error: 152.8793 - val_loss: 33840.9805 - val_mean_absolute_error: 183.9183
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23056.7207 - mean_absolute_error: 150.6862 - val_loss: 33641.3125 - val_mean_absolute_error: 183.3747
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22955.1582 - mean_absolute_error: 150.3943 - val_loss: 33499.2500 - val_mean_absolute_error: 182.9869
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22595.1328 - mean_absolute_error: 149.1773 - val_loss: 33350.4648 - val_mean_absolute_error: 182.5799
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22941.0215 - mean_absolute_error: 150.2321 - val_loss: 33172.3008 - val_mean_absolute_error: 182.0913
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22657.9531 - mean_absolute_error: 149.3756 - val_loss: 32952.5078 - val_mean_absolute_error: 181.4868
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22545.3047 - mean_absolute_error: 148.9604 - val_loss: 32607.8574 - val_mean_absolute_error: 180.5347
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22261.8730 - mean_absolute_error: 148.0077 - val_loss: 32083.1621 - val_mean_absolute_error: 179.0756
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21834.3066 - mean_absolute_error: 146.5063 - val_loss: 31313.0820 - val_mean_absolute_error: 176.9123
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20584.1523 - mean_absolute_error: 142.3020 - val_loss: 30165.8750 - val_mean_absolute_error: 173.6396
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20322.2598 - mean_absolute_error: 141.2502 - val_loss: 28558.5469 - val_mean_absolute_error: 168.9477
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18495.0254 - mean_absolute_error: 134.6585 - val_loss: 26558.6348 - val_mean_absolute_error: 162.9215
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16549.3125 - mean_absolute_error: 127.2182 - val_loss: 24159.8398 - val_mean_absolute_error: 155.3853
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15107.6689 - mean_absolute_error: 121.4506 - val_loss: 21345.5742 - val_mean_absolute_error: 146.0492
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12483.0879 - mean_absolute_error: 110.1041 - val_loss: 18007.0938 - val_mean_absolute_error: 134.1317
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9865.6689 - mean_absolute_error: 97.3006 - val_loss: 13806.2266 - val_mean_absolute_error: 117.4341
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7043.0737 - mean_absolute_error: 81.5297 - val_loss: 10295.0352 - val_mean_absolute_error: 101.3900
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4440.6919 - mean_absolute_error: 64.0141 - val_loss: 7309.0381 - val_mean_absolute_error: 85.4035
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2739.7197 - mean_absolute_error: 48.8222 - val_loss: 4718.8413 - val_mean_absolute_error: 68.5826
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1337.8297 - mean_absolute_error: 30.9143 - val_loss: 2705.6360 - val_mean_absolute_error: 51.8677
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 547.3909 - mean_absolute_error: 17.6566 - val_loss: 1444.0369 - val_mean_absolute_error: 37.8014
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 379.2834 - mean_absolute_error: 16.0820 - val_loss: 908.2349 - val_mean_absolute_error: 29.8864
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 351.3942 - mean_absolute_error: 16.1961 - val_loss: 719.3374 - val_mean_absolute_error: 26.5387
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 384.5674 - mean_absolute_error: 17.8629 - val_loss: 740.8879 - val_mean_absolute_error: 26.9417
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 376.5691 - mean_absolute_error: 17.4179 - val_loss: 864.7947 - val_mean_absolute_error: 29.1506
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 352.6636 - mean_absolute_error: 16.6904 - val_loss: 972.7548 - val_mean_absolute_error: 30.9470
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 358.4494 - mean_absolute_error: 16.4515 - val_loss: 1035.9083 - val_mean_absolute_error: 31.9512
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 339.3499 - mean_absolute_error: 15.8606 - val_loss: 1108.0121 - val_mean_absolute_error: 33.0638
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 318.9087 - mean_absolute_error: 14.9979 - val_loss: 1159.3864 - val_mean_absolute_error: 33.8340
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 356.6752 - mean_absolute_error: 16.2184 - val_loss: 1084.1403 - val_mean_absolute_error: 32.6998
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 347.0461 - mean_absolute_error: 16.2117 - val_loss: 1048.1625 - val_mean_absolute_error: 32.1460
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 345.4870 - mean_absolute_error: 16.0465 - val_loss: 1072.3660 - val_mean_absolute_error: 32.5237
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 331.8814 - mean_absolute_error: 15.4894 - val_loss: 1031.4227 - val_mean_absolute_error: 31.8870
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 349.3546 - mean_absolute_error: 16.5195 - val_loss: 1009.2662 - val_mean_absolute_error: 31.5373
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 321.8265 - mean_absolute_error: 15.5194 - val_loss: 951.1385 - val_mean_absolute_error: 30.6019
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 312.0449 - mean_absolute_error: 15.3250 - val_loss: 938.5401 - val_mean_absolute_error: 30.3987
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 338.8702 - mean_absolute_error: 15.9382 - val_loss: 1054.1910 - val_mean_absolute_error: 32.2609
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 304.4721 - mean_absolute_error: 14.8209 - val_loss: 1003.3339 - val_mean_absolute_error: 31.4597
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 269.9848 - mean_absolute_error: 13.8694 - val_loss: 909.6129 - val_mean_absolute_error: 29.9306
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 272.2556 - mean_absolute_error: 13.9120 - val_loss: 944.4782 - val_mean_absolute_error: 30.5282
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 234.4630 - mean_absolute_error: 12.2600 - val_loss: 743.9228 - val_mean_absolute_error: 27.0299
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 190.3153 - mean_absolute_error: 11.3614 - val_loss: 653.8081 - val_mean_absolute_error: 25.3154
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 176.6334 - mean_absolute_error: 11.1718 - val_loss: 569.4369 - val_mean_absolute_error: 23.6041
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 137.5737 - mean_absolute_error: 10.0067 - val_loss: 596.7465 - val_mean_absolute_error: 24.2145
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 137.5077 - mean_absolute_error: 9.2905 - val_loss: 371.0375 - val_mean_absolute_error: 18.9378
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 131.7997 - mean_absolute_error: 10.1381 - val_loss: 471.6226 - val_mean_absolute_error: 21.4979
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 99.1675 - mean_absolute_error: 7.9557 - val_loss: 302.3798 - val_mean_absolute_error: 17.0669
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 88.4150 - mean_absolute_error: 7.8184 - val_loss: 325.2045 - val_mean_absolute_error: 17.7649
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 68.8194 - mean_absolute_error: 6.5361 - val_loss: 268.4262 - val_mean_absolute_error: 16.0902
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.1474 - mean_absolute_error: 5.1523 - val_loss: 172.3257 - val_mean_absolute_error: 12.7339
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3385 - mean_absolute_error: 4.7234 - val_loss: 167.3411 - val_mean_absolute_error: 12.5782
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.7357 - mean_absolute_error: 4.5868 - val_loss: 164.6974 - val_mean_absolute_error: 12.4976
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.7907 - mean_absolute_error: 4.1492 - val_loss: 91.6017 - val_mean_absolute_error: 9.0666
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.7600 - mean_absolute_error: 3.3841 - val_loss: 76.1386 - val_mean_absolute_error: 8.1840
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.3438 - mean_absolute_error: 2.8403 - val_loss: 55.0112 - val_mean_absolute_error: 6.8285
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.4073 - mean_absolute_error: 3.1429 - val_loss: 51.0250 - val_mean_absolute_error: 6.5783
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.3907 - mean_absolute_error: 2.6871 - val_loss: 50.1160 - val_mean_absolute_error: 6.5407
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.4388 - mean_absolute_error: 2.5871 - val_loss: 49.0836 - val_mean_absolute_error: 6.4825
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0842 - mean_absolute_error: 2.3749 - val_loss: 45.3782 - val_mean_absolute_error: 6.2175
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9155 - mean_absolute_error: 2.2951 - val_loss: 29.8895 - val_mean_absolute_error: 4.9427
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.3979 - mean_absolute_error: 2.5496 - val_loss: 26.1760 - val_mean_absolute_error: 4.5944
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.1656 - mean_absolute_error: 2.4600 - val_loss: 27.8509 - val_mean_absolute_error: 4.7760
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1057 - mean_absolute_error: 2.1899 - val_loss: 25.4967 - val_mean_absolute_error: 4.5505
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3346 - mean_absolute_error: 2.2165 - val_loss: 23.3903 - val_mean_absolute_error: 4.3357
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5767 - mean_absolute_error: 2.2649 - val_loss: 20.5441 - val_mean_absolute_error: 4.0243
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8948 - mean_absolute_error: 2.2969 - val_loss: 21.9441 - val_mean_absolute_error: 4.1924
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3875 - mean_absolute_error: 2.0943 - val_loss: 23.1158 - val_mean_absolute_error: 4.3296
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5779 - mean_absolute_error: 2.1099 - val_loss: 20.6089 - val_mean_absolute_error: 4.0492
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4001 - mean_absolute_error: 2.2075 - val_loss: 19.3754 - val_mean_absolute_error: 3.9176
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0460 - mean_absolute_error: 2.1302 - val_loss: 18.7954 - val_mean_absolute_error: 3.8573
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8111 - mean_absolute_error: 2.1429 - val_loss: 17.4647 - val_mean_absolute_error: 3.7049
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9863 - mean_absolute_error: 2.0127 - val_loss: 15.7807 - val_mean_absolute_error: 3.4928
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6273 - mean_absolute_error: 2.2659 - val_loss: 16.8553 - val_mean_absolute_error: 3.6371
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2671 - mean_absolute_error: 2.1368 - val_loss: 21.3068 - val_mean_absolute_error: 4.1580
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9352 - mean_absolute_error: 2.2553 - val_loss: 17.1529 - val_mean_absolute_error: 3.6805
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9851 - mean_absolute_error: 2.1491 - val_loss: 11.9118 - val_mean_absolute_error: 2.9266
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1026 - mean_absolute_error: 2.3122 - val_loss: 12.2703 - val_mean_absolute_error: 2.9886
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1207 - mean_absolute_error: 2.2358 - val_loss: 10.1316 - val_mean_absolute_error: 2.6192
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1071 - mean_absolute_error: 2.2799 - val_loss: 18.9477 - val_mean_absolute_error: 3.8928
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6089 - mean_absolute_error: 2.1614 - val_loss: 16.6088 - val_mean_absolute_error: 3.6218
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8098 - mean_absolute_error: 2.2440 - val_loss: 16.4865 - val_mean_absolute_error: 3.6080
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2142 - mean_absolute_error: 2.0487 - val_loss: 12.0876 - val_mean_absolute_error: 2.9792
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5330 - mean_absolute_error: 2.1601 - val_loss: 10.7748 - val_mean_absolute_error: 2.7583
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2888 - mean_absolute_error: 2.0674 - val_loss: 11.3542 - val_mean_absolute_error: 2.8714
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2429 - mean_absolute_error: 2.0631 - val_loss: 13.5494 - val_mean_absolute_error: 3.2165
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1039 - mean_absolute_error: 2.0145 - val_loss: 14.1448 - val_mean_absolute_error: 3.3069
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9708 - mean_absolute_error: 2.1111 - val_loss: 21.6882 - val_mean_absolute_error: 4.2147
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.7943 - mean_absolute_error: 2.5002 - val_loss: 14.0251 - val_mean_absolute_error: 3.2924
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1745 - mean_absolute_error: 2.2692 - val_loss: 10.2651 - val_mean_absolute_error: 2.6815
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1360 - mean_absolute_error: 1.9737 - val_loss: 12.1328 - val_mean_absolute_error: 3.0083
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1464 - mean_absolute_error: 2.2021 - val_loss: 11.3166 - val_mean_absolute_error: 2.8803
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5576 - mean_absolute_error: 1.9237 - val_loss: 13.1835 - val_mean_absolute_error: 3.1729
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6934 - mean_absolute_error: 1.9865 - val_loss: 14.0738 - val_mean_absolute_error: 3.3063
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7702 - mean_absolute_error: 2.1646 - val_loss: 11.0217 - val_mean_absolute_error: 2.8401
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0174 - mean_absolute_error: 1.9974 - val_loss: 9.4527 - val_mean_absolute_error: 2.5441
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2930 - mean_absolute_error: 2.1232 - val_loss: 9.4545 - val_mean_absolute_error: 2.5450
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8965 - mean_absolute_error: 2.0156 - val_loss: 11.6316 - val_mean_absolute_error: 2.9436
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0100 - mean_absolute_error: 2.1712 - val_loss: 14.0226 - val_mean_absolute_error: 3.3056
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6368 - mean_absolute_error: 2.2003 - val_loss: 16.2120 - val_mean_absolute_error: 3.5905
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0266 - mean_absolute_error: 2.2479 - val_loss: 13.9930 - val_mean_absolute_error: 3.3022
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
